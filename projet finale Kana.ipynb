# %%
# exploration de la strcuture des donnees 
# importation des donnees de l'Ademe a l'aide du pachage pandas
# !pip install pynsee

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pynsee
import pynsee.download

# %%
df = pd.read_csv(("C:/Users/DILANE/Documents/df/IGT - Pouvoir_de_réchauffement_global.csv"), sep=",")

# %%
df
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %% [markdown]
# Exercice 1:

# %% [markdown]
# 1)les 10 premieres valeurs

# %%
print(df.head(10))
# Out:
#   INSEE commune                  Commune  Agriculture  Autres transports  \
# 0         01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1         01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2         01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3         01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4         01006                  AMBLEON   448.966808                NaN
# 5         01007                 AMBRONAY  4390.996698         132.968268
# 6         01008                 AMBUTRIX   489.648726          60.233517
# 7         01009         ANDERT-ET-CONDON   676.468367                NaN
# 8         01010                ANGLEFORT  1070.411510         143.815664
# 9         01011                 APREMONT  2010.790441                NaN
#
#    Autres transports international  CO2 biomasse hors-total      Déchets  \
# 0                              NaN               432.751835   101.430476
# ...

# %% [markdown]
# les 15 derniers valeurs

# %%
print(df.tail(15))
# Out:
#       INSEE commune              Commune  Agriculture  Autres transports  \
# 35783         95628           VALMONDOIS   646.421867           9.055189
# 35784         95633          VAUDHERLAND    48.361025                NaN
# 35785         95637              VAUREAL   203.969473          93.811651
# 35786         95641               VEMARS  1510.886844         146.089307
# 35787         95651             VETHEUIL   125.928390         175.096168
# 35788         95652              VIARMES   252.094735          55.168176
# 35789         95656    VIENNE-EN-ARTHIES   324.827105                NaN
# 35790         95658                VIGNY  1289.190261                NaN
# 35791         95660  VILLAINES-SOUS-BOIS   447.132894          18.996282
# 35792         95675             VILLERON  1335.123315           4.975886
# 35793         95676   VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678        VILLIERS-ADAM   698.630772                NaN
# ...

# %% [markdown]
# un echantillons aleatoire de 10 valeurs

# %%
print(df.sample(10))
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 21030         55388         NOYERS-AUZECOURT  4443.755784                NaN
# 5111          15013          AURIAC-L'EGLISE  5745.731940                NaN
# 20860         55188                FLASSIGNY  1544.265060                NaN
# 19356         51599               VAUDEMANGE  1748.434405         271.339977
# 1683          04186  SAINT-LAURENT-DU-VERDON   474.971887                NaN
# 5679          16354           SAINTE-SOULINE  1015.205782                NaN
# 20605         54510               SORNEVILLE   845.778675                NaN
# 26092         64500        SALLES-MONGISCARD  1311.877036                NaN
# 18463         50229                  HAMELIN  1956.189733                NaN
# 29483         72360                   TRANGE  2991.267882                NaN
#
#        Autres transports international  CO2 biomasse hors-total     Déchets  \
# ...

# %% [markdown]
# 2) Tirer 5% de l'échantillon sans remise:

# %%
print(df.sample(10))
# Out:
#       INSEE commune           Commune  Agriculture  Autres transports  \
# 2576          08194            GLAIRE  1038.946462         399.695650
# 10576         28373         SENONCHES  2657.240280                NaN
# 605           02203            COINCY  1995.183907                NaN
# 31641         79048         LA CRECHE  4846.988773         146.246300
# 8062          23210     SAINT-MAIXANT  3467.612955           8.324178
# 9839          27256  LA FORET-DU-PARC  1675.557133         122.623489
# 3730          11110         COUSTOUGE   192.864261                NaN
# 14387         37248           SEUILLY  1441.791664                NaN
# 17986         48146     SAINTE-ENIMIE  7842.355195                NaN
# 34571         88338        ORTONCOURT  1271.125560                NaN
#
#        Autres transports international  CO2 biomasse hors-total     Déchets  \
# 2576                         21.051866              5987.567521  121.134702
# ...

# %% [markdown]
# 2) Tirer 5% de l'échantillon sans remise

# %%
n = int(len(df) * 0.05)
sample = df.sample(n, replace=False)
print(sample)
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 2107          07048                CHALENCON   643.193575                NaN
# 25801         64203                    DOUMY  1110.223012                NaN
# 30017         74236  SAINT-GERVAIS-LES-BAINS   535.238511          19.198286
# 14970         39025                    AUGEA  1544.543343          41.180935
# 20441         54340                    MAMEY  1045.166649                NaN
# ...             ...                      ...          ...                ...
# 22402         58222                      RIX  1440.170214          79.720422
# 9940          27374                LOUVERSEY  1578.928726          33.508076
# 32144         80256        DREUIL-LES-AMIENS   643.850563         474.226116
# 17250         46040                CABRERETS  4713.558312                NaN
# 8688          25029                  AUBONNE  3385.110381                NaN
#
# ...

# %% [markdown]
# 3)Ne conserver que les 10 premières lignes et tirer aléatoirement dans celles-ci pour obtenir un DataFrame de 100 données.

# %%
df_10 = df.head(10)
sample = df_10.sample(100, replace=True)
print(sample)
# Out:
#    INSEE commune                  Commune  Agriculture  Autres transports  \
# 0          01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 2          01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 9          01011                 APREMONT  2010.790441                NaN
# 2          01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 6          01008                 AMBUTRIX   489.648726          60.233517
# ..           ...                      ...          ...                ...
# 9          01011                 APREMONT  2010.790441                NaN
# 2          01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 4          01006                  AMBLEON   448.966808                NaN
# 5          01007                 AMBRONAY  4390.996698         132.968268
# 9          01011                 APREMONT  2010.790441                NaN
#
#     Autres transports international  CO2 biomasse hors-total      Déchets  \
# ...

# %% [markdown]
# 4)Faire 100 tirages à partir des 6 premières lignes avec une probabilité de 1/2 pour la première observation et une probabilité uniforme pour les autres

# %%
df_6 = df.head(6)
df_6
# Out:
#   INSEE commune                  Commune  Agriculture  Autres transports  \
# 0         01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1         01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2         01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3         01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4         01006                  AMBLEON   448.966808                NaN
# 5         01007                 AMBRONAY  4390.996698         132.968268
#
#    Autres transports international  CO2 biomasse hors-total      Déchets  \
# 0                              NaN               432.751835   101.430476
# 1                              NaN               140.741660   140.675439
# 2                              NaN             10313.446515  5314.314445
# 3                              NaN              1144.429311   216.217508
# 4                              NaN                77.033834    48.401549
# ...

# %% [markdown]
# creation des poids pour l'echantillons

# %%
poids = [0.5] + [0.5 / (len(df) - 1)] * (len(df )- 1)
poids
# Out:
# [0.5,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
#  1.3967650920468195e-05,
# ...

# %% [markdown]
# éffectuer les tirages et afficher les tirages

# %%
tirage = df.sample(n = 100, replace = True, weights = poids)
tirage
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 33949         86189                  PAYROUX  9877.186153                NaN
# 28779         71217     GERMOLLES-SUR-GROSNE  2705.190669                NaN
# ...             ...                      ...          ...                ...
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 29162         72024                LA BAZOGE  5051.472170                NaN
# 30122         76014      ANGERVILLE-L'ORCHER  3177.761737                NaN
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
#
# ...

# %% [markdown]
# 5)Faire la même chose sur df_city

# %%
# !pip install pynsee

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pynsee
import pynsee.download

# %%
df_city = pynsee.download.download_file("FILOSOFI_COM_2016")
# Out:
# Extracting: 100%|██████████| 10.6M/10.6M [00:00<00:00, 168MB/s]

# %%
df_city
# Out:
#       CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 0      01001  L'Abergement-Clémenciat         313           795.5
# 1      01002    L'Abergement-de-Varey         101             248
# 2      01004        Ambérieu-en-Bugey        6363           14228
# 3      01005      Ambérieux-en-Dombes         633          1662.5
# 4      01006                  Ambléon         NaN             NaN
# ...      ...                      ...         ...             ...
# 34927  97420           Sainte-Suzanne        7827           23118
# 34928  97421                  Salazie        2358            6967
# 34929  97422                Le Tampon       27916         73468.5
# 34930  97423        Les Trois-Bassins        2386            7105
# 34931  97424                   Cilaos        2038            5603
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 0                   22679    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
# 1) les 10 premiers valeurs

# %%
print(df_city.head(10))
# Out:
#   CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 0  01001  L'Abergement-Clémenciat         313           795.5
# 1  01002    L'Abergement-de-Varey         101             248
# 2  01004        Ambérieu-en-Bugey        6363           14228
# 3  01005      Ambérieux-en-Dombes         633          1662.5
# 4  01006                  Ambléon         NaN             NaN
# 5  01007                 Ambronay        1087            2684
# 6  01008                 Ambutrix         297             736
# 7  01009         Andert-et-Condon         141             331
# 8  01010                Anglefort         441          1061.5
# 9  01011                 Apremont         143           364.5
#
#                 MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 0               22679    NaN    NaN        NaN        NaN        NaN  ...
# 1  24382.083333333336    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
# #les 15 derniers valeurs

# %%
print(df_city.tail(15))
# Out:
#       CODGEO             LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 34917  97410       Saint-Benoît       13240           38167
# 34918  97411        Saint-Denis       57567        145395.5
# 34919  97412       Saint-Joseph       14070           37848
# 34920  97413          Saint-Leu       12331         34853.5
# 34921  97414        Saint-Louis       17890         53130.5
# 34922  97415         Saint-Paul       37064          105829
# 34923  97416       Saint-Pierre       31373         85424.5
# 34924  97417     Saint-Philippe        1781            4935
# 34925  97418       Sainte-Marie       11640         33780.5
# 34926  97419        Sainte-Rose        2308            6710
# 34927  97420     Sainte-Suzanne        7827           23118
# 34928  97421            Salazie        2358            6967
# 34929  97422          Le Tampon       27916         73468.5
# 34930  97423  Les Trois-Bassins        2386            7105
# 34931  97424             Cilaos        2038            5603
#
# ...

# %% [markdown]
# #échantillon aleatoire de 10 valeurs

# %%
print(df_city.sample(10))
# Out:
#       CODGEO              LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 34073  89255             Michery         456          1072.5
# 12390  33069          Le Bouscat       11454         24258.5
# 30096  77085  Chanteloup-en-Brie        1295          3882.5
# 10659  2A271   Sarrola-Carcopino        1213          2898.5
# 21036  57269            Guénange        2937          6903.5
# 5815   17263    Nieul-le-Virouil         242             538
# 31600  80605               Offoy          93           220.5
# 10725  2B067           Carpineto         NaN             NaN
# 28268  71471         Saint-Privé         NaN             NaN
# 30145  77136        Courquetaine          72           201.5
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 34073             22716.5    NaN    NaN        NaN        NaN        NaN  ...
# 12390               24144     62      9        NaN         11         11  ...
# ...

# %% [markdown]
# 2) Tirer 5 pourcent de l’échantillon sans remise

# %%
n = int(len(df_city) * 0.05)
sample = df_city.sample(n, replace=False)
print(sample)
# Out:
#       CODGEO               LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 17647  49231              Nuaillé         586            1522
# 28056  71249               Laives         428          1053.5
# 5355   16174             Julienne         194           493.5
# 16743  45333              Vennecy         637          1820.5
# 18682  51559              Suippes        1268            3121
# ...      ...                  ...         ...             ...
# 14659  39119          Le Chateley         NaN             NaN
# 1188   02830             Wassigny         379             925
# 25931  66037  Canet-en-Roussillon        7184           13218
# 2412   08052           Bayonville         NaN             NaN
# 11017  30095             Corconne         227           548.5
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 17647  21160.777777777777    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
# 3))Ne conserver que les 10 premières lignes et tirer aléatoirement dans celles-ci pour obtenir un DataFrame de 100 données.

# %%
df_city_10 = df_city.head(10)
sample = df_city_10.sample(100, replace=True)
print(sample)
# Out:
#    CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 1   01002    L'Abergement-de-Varey         101             248
# 0   01001  L'Abergement-Clémenciat         313           795.5
# 9   01011                 Apremont         143           364.5
# 8   01010                Anglefort         441          1061.5
# 3   01005      Ambérieux-en-Dombes         633          1662.5
# ..    ...                      ...         ...             ...
# 7   01009         Andert-et-Condon         141             331
# 7   01009         Andert-et-Condon         141             331
# 6   01008                 Ambutrix         297             736
# 3   01005      Ambérieux-en-Dombes         633          1662.5
# 3   01005      Ambérieux-en-Dombes         633          1662.5
#
#                  MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 1   24382.083333333336    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
# 4)Faire 100 tirages à partir des 6 premières lignes avec une probabilité de 1/2 pour la première observation et une probabilité uniforme pour les autres

# %%
df_city_6 = df_city.head(6)
df_city_6
# Out:
#   CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 0  01001  L'Abergement-Clémenciat         313           795.5
# 1  01002    L'Abergement-de-Varey         101             248
# 2  01004        Ambérieu-en-Bugey        6363           14228
# 3  01005      Ambérieux-en-Dombes         633          1662.5
# 4  01006                  Ambléon         NaN             NaN
# 5  01007                 Ambronay        1087            2684
#
#                 MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 0               22679    NaN    NaN        NaN        NaN        NaN  ...
# 1  24382.083333333336    NaN    NaN        NaN        NaN        NaN  ...
# 2               19721     49     17         19         22         22  ...
# 3               23378    NaN    NaN        NaN        NaN        NaN  ...
# 4                 NaN    NaN    NaN        NaN        NaN        NaN  ...
# 5  22146.451612903224     57    NaN        NaN        NaN        NaN  ...
#
# ...

# %% [markdown]
# #creation des poids pour l'echantillon

# %%
poids = [0.5] + [0.5 / (len(df_city) - 1)] * (len(df_city )- 1)
poids
# Out:
# [0.5,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
#  1.4313933182559904e-05,
# ...

# %% [markdown]
# #effectuer les tirages et les affciher

# %%
tirage = df_city.sample(n = 100, replace = True, weights = poids)
tirage
# Out:
#       CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 2702   08379    Saint-Étienne-à-Arnes          97           248.5
# 1721   05017           La Bâtie-Neuve         973          2479.5
# 8702   25333                  Laviron         145           356.5
# 18692  51570        Le Thoult-Trosnay          42             102
# 0      01001  L'Abergement-Clémenciat         313           795.5
# ...      ...                      ...         ...             ...
# 14818  39305                  La Loye         218             546
# 23574  62048                   Auchel        4270         10235.5
# 29652  76372                   Illois         144             397
# 0      01001  L'Abergement-Clémenciat         313           795.5
# 34615  93031         Épinay-sur-Seine       18273           51698
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 2702   21772.666666666668    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
# Exercice 2:

# %% [markdown]
# 1)Vérifier les types des variables. S’assurer que les types des variables communes aux deux bases sont cohérents. Pour les variables qui ne sont pas en type float alors qu’elles devraient l’être, modifier leur type.

# %%
print(df_city.dtypes)
# Out:
# CODGEO             object
# LIBGEO             object
# NBMENFISC16        object
# NBPERSMENFISC16    object
# MED16              object
# PIMP16             object
# TP6016             object
# TP60AGE116         object
# TP60AGE216         object
# TP60AGE316         object
# TP60AGE416         object
# TP60AGE516         object
# TP60AGE616         object
# TP60TOL116         object
# TP60TOL216         object
# PACT16             object
# PTSA16             object
# PCHO16             object
# PBEN16             object
# PPEN16             object
# PPAT16             object
# PPSOC16            object
# PPFAM16            object
# PPMINI16           object
# PPLOGT16           object
# PIMPOT16           object
# D116               object
# D916               object
# RD16               object
# dtype: object

# %%
print(df.dtypes)
# Out:
# INSEE commune                       object
# Commune                             object
# Agriculture                        float64
# Autres transports                  float64
# Autres transports international    float64
# CO2 biomasse hors-total            float64
# Déchets                            float64
# Energie                            float64
# Industrie hors-énergie             float64
# Résidentiel                        float64
# Routier                            float64
# Tertiaire                          float64
# dtype: object

# %% [markdown]
# 1) verifions les dimenssions des Dataframes

# %%
print(df_city.shape)
# Out:
# (34932, 29)

# %%
print(df.shape)
# Out:
# (35798, 12)

# %% [markdown]
# 2) nombre de valeurs uniques

# %%
print(df_city['CODGEO'].nunique())
# Out:
# 34932

# %%
print(df_city['LIBGEO'].nunique())
# Out:
# 32676

# %% [markdown]
# #verifions les nombres de valeurs uniques des variable geographique pour le df

# %%
print(df['INSEE commune'].nunique())
# Out:
# 35798

# %%
print(df['Commune'].nunique())
# Out:
# 33338

# %% [markdown]
# 3)Identifier dans df_city les noms de communes qui correspondent à plusieurs codes communes et sélectionner leurs codes. En d’autres termes, identifier les CODGEO tels qu’il existe des doublons de LIBGEO et les stocker dans un vecteur x (conseil: faire attention à l’index de x)

# %%
duplicates = df_city[df_city['LIBGEO'].duplicated(keep=False)]
x = duplicates['CODGEO'].unique()
print(duplicates)
# Out:
#       CODGEO          LIBGEO NBMENFISC16 NBPERSMENFISC16               MED16  \
# 9      01011        Apremont         143           364.5   23246.08695652174
# 23     01027           Balan         647            1812  23696.666666666668
# 26     01030      Beauregard         363           884.5               21003
# 35     01039            Béon         199             477               20663
# 38     01042             Bey         113             295   24139.33333333333
# ...      ...             ...         ...             ...                 ...
# 34921  97414     Saint-Louis       17890         53130.5               12843
# 34922  97415      Saint-Paul       37064          105829  16279.354838709676
# 34923  97416    Saint-Pierre       31373         85424.5  14709.333333333334
# 34925  97418    Sainte-Marie       11640         33780.5   16722.38095238095
# 34927  97420  Sainte-Suzanne        7827           23118  15110.666666666666
#
# ...

# %% [markdown]
# On se focalise temporairement sur les observations où le libellé comporte plus de deux codes communes différents

# %% [markdown]
# 1)Regarder dans df_city ces observations

# %%
df_city['num_codes'] = df_city['CODGEO'].str.count(',')
multi_codes = df_city[df_city['num_codes'] > 1]
print(df_city)
# Out:
#       CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 0      01001  L'Abergement-Clémenciat         313           795.5
# 1      01002    L'Abergement-de-Varey         101             248
# 2      01004        Ambérieu-en-Bugey        6363           14228
# 3      01005      Ambérieux-en-Dombes         633          1662.5
# 4      01006                  Ambléon         NaN             NaN
# ...      ...                      ...         ...             ...
# 34927  97420           Sainte-Suzanne        7827           23118
# 34928  97421                  Salazie        2358            6967
# 34929  97422                Le Tampon       27916         73468.5
# 34930  97423        Les Trois-Bassins        2386            7105
# 34931  97424                   Cilaos        2038            5603
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 0                   22679    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
# 2)Pour mieux y voir, réordonner la base obtenue par ordre alphabétique

# %%
multi_codes = multi_codes.sort_values('LIBGEO')
print(multi_codes)
# Out:
# Empty DataFrame
# Columns: [CODGEO, LIBGEO, NBMENFISC16, NBPERSMENFISC16, MED16, PIMP16, TP6016, TP60AGE116, TP60AGE216, TP60AGE316, TP60AGE416, TP60AGE516, TP60AGE616, TP60TOL116, TP60TOL216, PACT16, PTSA16, PCHO16, PBEN16, PPEN16, PPAT16, PPSOC16, PPFAM16, PPMINI16, PPLOGT16, PIMPOT16, D116, D916, RD16, num_codes]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# 3)Déterminer la taille moyenne (variable nombre de personnes: NBPERSMENFISC16) et quelques statistiques descriptives de ces données. Comparer aux mêmes statistiques sur les données où libellés et codes communes coïncident

# %%
print(df_city[df_city['num_codes'] == 0]['NBPERSMENFISC16'].describe())
# Out:
# count     31405
# unique     7878
# top         108
# freq         55
# Name: NBPERSMENFISC16, dtype: object

# %%
print(multi_codes['NBPERSMENFISC16'].describe())
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: NBPERSMENFISC16, dtype: object

# %% [markdown]
# 4)Vérifier les grandes villes (plus de 100 000 personnes), la proportion de villes pour lesquelles un même nom est associé à différents codes commune.

# %%
df_city
# Out:
#       CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 0      01001  L'Abergement-Clémenciat         313           795.5
# 1      01002    L'Abergement-de-Varey         101             248
# 2      01004        Ambérieu-en-Bugey        6363           14228
# 3      01005      Ambérieux-en-Dombes         633          1662.5
# 4      01006                  Ambléon         NaN             NaN
# ...      ...                      ...         ...             ...
# 34927  97420           Sainte-Suzanne        7827           23118
# 34928  97421                  Salazie        2358            6967
# 34929  97422                Le Tampon       27916         73468.5
# 34930  97423        Les Trois-Bassins        2386            7105
# 34931  97424                   Cilaos        2038            5603
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 0                   22679    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
#  Filtrer les grandes villes (plus de 100 000 personnes)

# %% [markdown]
# 5)Vérifier dans df_city les villes dont le libellé est égal à Montreuil. Vérifier également celles qui contiennent le terme ‘Saint-Denis’

# %%
montreuil = df_city[df_city['LIBGEO'] == 'Montreuil']
montreuil
# Out:
#       CODGEO     LIBGEO NBMENFISC16 NBPERSMENFISC16              MED16 PIMP16  \
# 10153  28267  Montreuil         215             503  24823.04347826087    NaN
# 24099  62588  Montreuil         994            1951              18762    NaN
# 32750  85148  Montreuil         340           883.5              19340    NaN
# 34622  93048  Montreuil       43996          108682              18428     55
#
#       TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ... PPEN16 PPAT16 PPSOC16  \
# 10153    NaN        NaN        NaN        NaN  ...    NaN    NaN     NaN
# 24099    NaN        NaN        NaN        NaN  ...    NaN    NaN     NaN
# 32750    NaN        NaN        NaN        NaN  ...    NaN    NaN     NaN
# 34622     26         29         23         30  ...     18    6.3     7.5
#
#       PPFAM16 PPMINI16 PPLOGT16 PIMPOT16               D116   D916  \
# 10153     NaN      NaN      NaN      NaN                NaN    NaN
# 24099     NaN      NaN      NaN      NaN                NaN    NaN
# ...

# %%
saint_denis = df_city[df_city['LIBGEO'].str.contains('Saint-Denis')]
print(saint_denis)
# Out:
#       CODGEO                    LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 290    01344     Saint-Denis-lès-Bourg        2562            6036
# 291    01345      Saint-Denis-en-Bugey         965            2280
# 1177   02818      Villiers-Saint-Denis         365             901
# 3906   11339               Saint-Denis         224           473.5
# 4824   14571    Saint-Denis-de-Mailloc         124           298.5
# 4825   14572       Saint-Denis-de-Méré         331           770.5
# 5874   17323      Saint-Denis-d'Oléron         733            1401
# 6231   18204      Saint-Denis-de-Palin         125           314.5
# 7031   21442         Morey-Saint-Denis         285           663.5
# 8518   25129     Chassagne-Saint-Denis          50             116
# 9785   27530    Saint-Denis-d'Augerons         NaN             NaN
# 9786   27531     Saint-Denis-des-Monts          89           216.5
# 9787   27533    Saint-Denis-le-Ferment         199             491
# ...

# %% [markdown]
# Exercice 3:

# %% [markdown]
# 1)fixon la variable comme indice

# %%
df = df.set_index('INSEE commune')
df_city = df_city.set_index('CODGEO')

# %%
print(df)
# Out:
#                Agriculture  Autres transports  \
# INSEE commune
# 01001          3711.425991                NaN
# 01002           475.330205                NaN
# 01004           499.043526         212.577908
# 01005          1859.160954                NaN
# 01006           448.966808                NaN
# ...                    ...                ...
# 95676          1628.065094                NaN
# 95678           698.630772                NaN
# 95680           107.564967                NaN
# 95682          1090.890170                NaN
# 95690          1495.103542                NaN
#
#                Autres transports international  CO2 biomasse hors-total  \
# INSEE commune
# 01001                                      NaN               432.751835
# 01002                                      NaN               140.741660
# 01004                                      NaN             10313.446515
# 01005                                      NaN              1144.429311
# ...

# %%
print(df_city)
# Out:
#       CODGEO                   LIBGEO NBMENFISC16 NBPERSMENFISC16  \
# 0      01001  L'Abergement-Clémenciat         313           795.5
# 1      01002    L'Abergement-de-Varey         101             248
# 2      01004        Ambérieu-en-Bugey        6363           14228
# 3      01005      Ambérieux-en-Dombes         633          1662.5
# 4      01006                  Ambléon         NaN             NaN
# ...      ...                      ...         ...             ...
# 34927  97420           Sainte-Suzanne        7827           23118
# 34928  97421                  Salazie        2358            6967
# 34929  97422                Le Tampon       27916         73468.5
# 34930  97423        Les Trois-Bassins        2386            7105
# 34931  97424                   Cilaos        2038            5603
#
#                     MED16 PIMP16 TP6016 TP60AGE116 TP60AGE216 TP60AGE316  ...  \
# 0                   22679    NaN    NaN        NaN        NaN        NaN  ...
# ...

# %% [markdown]
#     2)creation d'une variable de departement dans df et df_city

# %%
df['dep'] = df.index.str[:2]

# %%
df['dep']
# Out:
# INSEE commune
# 01001    01
# 01002    01
# 01004    01
# 01005    01
# 01006    01
#          ..
# 95676    95
# 95678    95
# 95680    95
# 95682    95
# 95690    95
# Name: dep, Length: 35798, dtype: object

# %%
df_city['dep'] = df_city['CODGEO'].apply(lambda x: str(x)[:2])
df_city['dep']
# Out:
# 0        01
# 1        01
# 2        01
# 3        01
# 4        01
#          ..
# 34927    97
# 34928    97
# 34929    97
# 34930    97
# 34931    97
# Name: dep, Length: 34932, dtype: object

# %% [markdown]
# 3)Calculer les émissions totales par secteur pour chaque département. Mettre en log ces résultats dans un objet df_log. Garder 5 départements et produire un barplot

# %% [markdown]
# #Calculer les émissions totales par secteur pour chaque département

# %%
sum_by_sector = df.groupby(['Commune', 'SECTOR'])['EMISSIONS'].sum().reset_index()

# %% [markdown]
# 4)Repartir de df. Calculer les émissions totales par département et sortir la liste des 10 principaux émetteurs de CO2 et des 5 départements les moins émetteurs. Sans faire de merge, regarder les caractéristiques de ces départements (population et niveau de vie)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_top_5_departments, x='secteur', y='emissions_log', hue='dep')
plt.xlabel('Secteur')
plt.ylabel('Log des émissions totales')
plt.title('Émissions totales par secteur pour les 5 départements')
plt.show()

# %% [markdown]
# Exercice 4:

# %%
df_copy = df.copy()  
df_copy
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %%
df_copy2 = df.copy()
df_copy2
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %% [markdown]
# 2)Utiliser la variable dep comme indice pour df_copy et retirer tout index pour df_copy2

# %%
df_copy.set_index('dep', inplace=True)
df_copy2.reset_index(drop=True, inplace=True)

# %% [markdown]
# 3)Importer le module timeit et comparer le temps d’exécution de la somme par secteur, pour chaque département, des émissions de CO2

# %%
# Importation du module timeit
import timeit

# %%
time_with_index = timeit.timeit(lambda: df_copy.groupby(df_copy.index).sum(),number = 100)
time_without_index = timeit.timeit(lambda: df_copy2.groupby('Commune').sum(), number = 100)

print(f"Temps avec index: {time_with_index}")
print(f"Temps sans index: {time_without_index}")
# Out:
# Temps avec index: 0.972705500000302
# Temps sans index: 4.168141899997863

# %% [markdown]
# Exercice 5:

# %%
df_wide = df.copy()
df_wide
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %% [markdown]
# 2)Restructuré les donnees:

# %%
df_long = pd.melt(df_wide, id_vars=['INSEE commune', 'Commune'], var_name='Secteur', value_name='Emissions')
df_long
# Out:
#        INSEE commune                  Commune      Secteur     Emissions
# 0              01001  L'ABERGEMENT-CLEMENCIAT  Agriculture   3711.425991
# 1              01002    L'ABERGEMENT-DE-VAREY  Agriculture    475.330205
# 2              01004        AMBERIEU-EN-BUGEY  Agriculture    499.043526
# 3              01005      AMBERIEUX-EN-DOMBES  Agriculture   1859.160954
# 4              01006                  AMBLEON  Agriculture    448.966808
# ...              ...                      ...          ...           ...
# 357975         95676       VILLERS-EN-ARTHIES    Tertiaire    235.439109
# 357976         95678            VILLIERS-ADAM    Tertiaire    403.404815
# 357977         95680          VILLIERS-LE-BEL    Tertiaire  13849.512001
# 357978         95682          VILLIERS-LE-SEC    Tertiaire     85.657725
# 357979         95690      WY-DIT-JOLI-VILLAGE    Tertiaire    147.867245
#
# [357980 rows x 4 columns]

# %% [markdown]
# 3)Faire la somme par secteur et représenter graphiquement:

# %%
df_secteur = df_long.groupby('Secteur')['Emissions'].sum()
print(df_secteur)
# Out:
# Secteur
# Agriculture                        8.790969e+07
# Autres transports                  6.535446e+06
# Autres transports international    2.223857e+07
# CO2 biomasse hors-total            6.351931e+07
# Déchets                            1.470358e+07
# Energie                            2.285203e+07
# Industrie hors-énergie             8.357368e+07
# Routier                            1.264932e+08
# Résidentiel                        6.384140e+07
# Tertiaire                          3.956273e+07
# Name: Emissions, dtype: float64

# %%
df_secteur.plot(kind='bar')
df_secteur.plot

# %% [markdown]
# 4)Garder, pour chaque département, le secteur le plus polluant

# %%
df_pollution = df_long.groupby(['Commune', 'Secteur'])['Emissions'].sum()
df_pollution
# Out:
# Commune    Secteur
# AAST       Agriculture                        1434.117894
#            Autres transports                     0.000000
#            Autres transports international       0.000000
#            CO2 biomasse hors-total             124.240530
#            Déchets                              23.539276
#                                                  ...
# ZUYTPEENE  Energie                               2.354558
#            Industrie hors-énergie                6.911213
#            Routier                             478.238925
#            Résidentiel                         203.820999
#            Tertiaire                           255.059035
# Name: Emissions, Length: 333380, dtype: float64

# %%
df_pollution = df_pollution.reset_index()
df_pollution
# Out:
#           Commune                          Secteur    Emissions
# 0            AAST                      Agriculture  1434.117894
# 1            AAST                Autres transports     0.000000
# 2            AAST  Autres transports international     0.000000
# 3            AAST          CO2 biomasse hors-total   124.240530
# 4            AAST                          Déchets    23.539276
# ...           ...                              ...          ...
# 333375  ZUYTPEENE                          Energie     2.354558
# 333376  ZUYTPEENE           Industrie hors-énergie     6.911213
# 333377  ZUYTPEENE                          Routier   478.238925
# 333378  ZUYTPEENE                      Résidentiel   203.820999
# 333379  ZUYTPEENE                        Tertiaire   255.059035
#
# [333380 rows x 3 columns]

# %%
df_pollution = df_pollution.loc[df_pollution.groupby('Commune')['Emissions'].idxmax()]
df_pollution
# Out:
#                      Commune      Secteur    Emissions
# 0                       AAST  Agriculture  1434.117894
# 17                ABAINVILLE      Routier  3458.045429
# 20                 ABANCOURT  Agriculture  2419.740682
# 30                 ABAUCOURT  Agriculture  2437.289953
# 40      ABAUCOURT-HAUTECOURT  Agriculture  3669.035424
# ...                      ...          ...          ...
# 333330                 ZUANI  Agriculture   376.828015
# 333340            ZUDAUSQUES  Agriculture  2143.870043
# 333357             ZUTKERQUE      Routier  5348.650356
# 333368             ZUYDCOOTE  Résidentiel  2009.397154
# 333370             ZUYTPEENE  Agriculture  3707.630709
#
# [33338 rows x 3 columns]

# %% [markdown]
# Exercicce 6:

# %% [markdown]
# 1)Repartir de `df_wide = df.copy()

# %%
df_wide = df.copy()
df_wide
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %% [markdown]
# 2)Reconstruire le DataFrame, au format long, des données d’émissions par secteur en gardant comme niveau d’analyse la commune puis faire la somme par département et secteur

# %%
df_long = df_wide.melt(id_vars=['Commune'], var_name='secteur', value_name='emissions')
df_long
# Out:
#                         Commune        secteur emissions
# 0       L'ABERGEMENT-CLEMENCIAT  INSEE commune     01001
# 1         L'ABERGEMENT-DE-VAREY  INSEE commune     01002
# 2             AMBERIEU-EN-BUGEY  INSEE commune     01004
# 3           AMBERIEUX-EN-DOMBES  INSEE commune     01005
# 4                       AMBLEON  INSEE commune     01006
# ...                         ...            ...       ...
# 393773       VILLERS-EN-ARTHIES      Tertiaire   235.439
# 393774            VILLIERS-ADAM      Tertiaire   403.405
# 393775          VILLIERS-LE-BEL      Tertiaire   13849.5
# 393776          VILLIERS-LE-SEC      Tertiaire   85.6577
# 393777      WY-DIT-JOLI-VILLAGE      Tertiaire   147.867
#
# [393778 rows x 3 columns]

# %% [markdown]
# #faire la somme par secteur

# %%
df_sum = df_long.groupby(['Commune', 'secteur'])['emissions'].sum().reset_index()
df_sum
# Out:
#           Commune                          secteur emissions
# 0            AAST                      Agriculture   1434.12
# 1            AAST                Autres transports         0
# 2            AAST  Autres transports international         0
# 3            AAST          CO2 biomasse hors-total   124.241
# 4            AAST                          Déchets   23.5393
# ...           ...                              ...       ...
# 366713  ZUYTPEENE                    INSEE commune     59669
# 366714  ZUYTPEENE           Industrie hors-énergie   6.91121
# 366715  ZUYTPEENE                          Routier   478.239
# 366716  ZUYTPEENE                      Résidentiel   203.821
# 366717  ZUYTPEENE                        Tertiaire   255.059
#
# [366718 rows x 3 columns]

# %% [markdown]
# 3)Passer au format wide pour avoir une ligne par secteur et une colonne par département

# %%
df_wide_sum = df_sum.pivot(index='secteur', columns='Commune', values='emissions')
df_wide_sum
# Out:
# Commune                             AAST ABAINVILLE   ABANCOURT ABAUCOURT  \
# secteur
# Agriculture                      1434.12     2768.8     2419.74   2437.29
# Autres transports                      0    73.0667     204.708         0
# Autres transports international        0          0           0         0
# CO2 biomasse hors-total          124.241    824.776     710.982   224.817
# Déchets                          23.5393    39.2762     145.467   40.2019
# Energie                                0    148.337     16.4819   2.35456
# INSEE commune                      64001      55001  5900160001     54001
# Industrie hors-énergie                 0    435.406     48.3785   6.91121
# Routier                          162.885    3458.05     1430.32   374.418
# Résidentiel                      58.0858    176.893     820.981   151.449
# Tertiaire                        85.1792    326.025     526.388   145.475
#
# Commune                         ABAUCOURT-HAUTECOURT ABBANS-DESSOUS  \
# ...

# %% [markdown]
# 4)Calculer, pour chaque secteur, la place du département dans la hiérarchie des émissions nationales

# %%
df_rank = df_wide_sum.rank(ascending=False, axis=1, method='min')
df_rank
# Out:
# Commune                             AAST  ABAINVILLE  ABANCOURT  ABAUCOURT  \
# secteur
# Agriculture                      18329.0      9962.0    11554.0    11472.0
# Autres transports                 9734.0      6313.0     2885.0     9734.0
# Autres transports international   2868.0      2868.0     2868.0     2868.0
# CO2 biomasse hors-total          29377.0     11170.0    12423.0    24229.0
# Déchets                          26184.0     20977.0     6306.0    20724.0
# Energie                          32184.0      5567.0    12001.0    17218.0
# INSEE commune                     9110.0     13756.0    12031.0    14307.0
# Industrie hors-énergie           32184.0      5610.0    12006.0    17221.0
# Routier                          30985.0      8220.0    14893.0    26298.0
# Résidentiel                      29358.0     19728.0     8508.0    21238.0
# Tertiaire                        26336.0     13492.0     9652.0    21347.0
#
# ...

# %% [markdown]
# 5)# Calculer le rang médian de chaque département dans la hiérarchie des émissions

# %%
df_median_rank = df_rank.median(axis=0)
df_median_rank
# Out:
# Commune
# AAST                    26336.0
# ABAINVILLE               9962.0
# ABANCOURT               11554.0
# ABAUCOURT               17221.0
# ABAUCOURT-HAUTECOURT    17218.0
#                          ...
# ZUANI                   31407.0
# ZUDAUSQUES              13080.0
# ZUTKERQUE                8928.0
# ZUYDCOOTE               11406.0
# ZUYTPEENE               15857.0
# Length: 33338, dtype: float64

# %% [markdown]
#  Obtenir les 10 départements ayant les rangs médians les plus élevés (les "mauvais élèves")

# %%
top_10_departments = df_median_rank.nlargest(10)
top_10_departments
# Out:
# Commune
# SOTZELING             33037.0
# URS                   32959.0
# MOLERE                32899.0
# OUSTE                 32899.0
# BIEUXY                32844.0
# REMAISNIL             32818.0
# CHARMES-EN-L'ANGLE    32800.0
# CRECHETS              32743.0
# CHAUFFECOURT          32738.0
# PANON                 32717.0
# dtype: float64
