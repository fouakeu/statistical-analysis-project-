# %%
#exercise 5 chapter 13
a = int(input("enter a value a : "))
b = a**0.5
c = round (b,2)
print("la racine caree est ",c)
# Out:
# enter a value a : 12
# la racine caree est  3.46

# %%
#exercise 9 chapter 13
a = int(input("enter a value a : "))
b = a//12
c = a%12
print(a,"compte",b,"poids est",c,"pouces")
# Out:
# enter a value a : 12
# 12 compte 1 poids est 0 pouces

# %%
#exercise 3 chapter 13
a =int(input("enter a value a : "))
if a%2 ==0:
    b= a//2
    print("le nombre de carte reduit est ",b)
else:
    b = (a-1)//2
    print('le nombre de cartes reduit est',b)
# Out:
# enter a value a : 32
# le nombre de carte reduit est  16

# %%
#exercoise 15 chapter 13
y = int(input("enter the year :"))
m = int(input("enter the month : "))
d = int(input("enter the day :"))
p = (14-m)//12
q =y-p
r = q + (q//4) - (q//100) + (q//400)
s = m + 12*p-2
t =(d + r + (31*s//12))%7
if t==0:
    print("the day is sunday")
elif t==1:
    print("the day is monday")
elif t==2:
    print("the day is tuesday")
elif t==3:
    print("the day is wenesday")
elif t==4:
    print("the day is thursday")
elif t==5:
    print("the day is friday")
elif t==6:
    print("the day is saturday")
# Out:
# enter the year :2015
# enter the month : 8
# enter the day :12
# the day is wenesday

# %%
#exercise13 chapter13
import random
a = int(input("enter a value : "))
b = random.randint(a,a+10)
print(b)
print("a "*b)
# Out:
# enter a value : 12
# 14
# a a a a a a a a a a a a a a

# %%
#exercise 1 chapter 13
x =int(input("enter a value x :"))
y =int(input("enter a value y:"))
exp = x**y
print("x^y est",exp)
# Out:
# enter a value x :8
# enter a value y:3
# x^y est 512

# %%
#exercise 7 chapter 13
import math
l = int(input("enter a value l :"))
h = int(input("enter a value h :"))
b = math.atan2 (h,l)
c = round(math.degrees(b),1)
print("la valeur en degrees est ",c)
# Out:
# enter a value l :12
# enter a value h :21
# la valeur en degrees est  60.3

# %%
#exercise 14 chapter 14
for i in range (0,201):
    if(i% 10 !=8):
        print("file",i,"jpg")
    else:
        print("NA")
# Out:
# file 0 jpg
# file 1 jpg
# file 2 jpg
# file 3 jpg
# file 4 jpg
# file 5 jpg
# file 6 jpg
# file 7 jpg
# NA
# file 9 jpg
# file 10 jpg
# file 11 jpg
# file 12 jpg
# file 13 jpg
# file 14 jpg
# file 15 jpg
# file 16 jpg
# file 17 jpg
# NA
# file 19 jpg
# file 20 jpg
# file 21 jpg
# file 22 jpg
# file 23 jpg
# file 24 jpg
# file 25 jpg
# file 26 jpg
# file 27 jpg
# NA
# file 29 jpg
# file 30 jpg
# file 31 jpg
# file 32 jpg
# file 33 jpg
# file 34 jpg
# file 35 jpg
# file 36 jpg
# file 37 jpg
# NA
# file 39 jpg
# file 40 jpg
# file 41 jpg
# file 42 jpg
# file 43 jpg
# file 44 jpg
# file 45 jpg
# file 46 jpg
# file 47 jpg
# NA
# file 49 jpg
# file 50 jpg
# file 51 jpg
# file 52 jpg
# file 53 jpg
# file 54 jpg
# file 55 jpg
# file 56 jpg
# file 57 jpg
# NA
# file 59 jpg
# file 60 jpg
# file 61 jpg
# file 62 jpg
# file 63 jpg
# file 64 jpg
# file 65 jpg
# file 66 jpg
# file 67 jpg
# NA
# file 69 jpg
# file 70 jpg
# file 71 jpg
# file 72 jpg
# file 73 jpg
# file 74 jpg
# file 75 jpg
# ...

# %%
#exercise 16 chapter 14
a = int(input("enter a ;"))
while a==0:
    a=float(input("enter again a value"))
b = int(input("enter b:"))
c=int(input("enter c:"))
d=int(input("enter d:"))
print("the equation is ","(",a,")","x^3 + (",b,")x^2 + ",c,"x +","d = 0")
for x in range (1,100):
    res=a*x*x*x+b*x*x*x+c*x+d
    if res==0:
        print("la solution est ",x)
# Out:
# enter a ;2
# enter b:3
# enter c:5
# enter d:6
# the equation is  ( 2 ) x^3 + ( 3 )x^2 +  5 x + d = 0

# %%
#exercise11 chapter 13
import random
for i in range (0,100):
    print(random.randint(50,60),end="  ")
# Out:
# 59  57  50  54  52  51  51  59  57  53  55  58  60  53  57  50  52  55  52  55  54  51  56  59  60  51  51  59  60  60  59  55  50  60  53  59  57  57  57  60  55  52  51  56  59  59  54  60  59  54  59  52  59  57  50  52  56  57  60  52  53  54  60  55  54  54  59  55  54  54  50  57  51  53  51  59  59  58  58  59  59  53  59  51  59  50  51  56  51  60  50  57  58  50  56  51  50  57  51  55

# %%
#exercise 8 chapter 13
def easter(y):
    c = y//100
    m = (15 + c - c//4 - (8*c+13)//25)%30
    n = (4+c-c//4)%7
    a = y%4
    b = y%7
    c = y%19
    d = (19*c+m)%30
    e = (2*a+4*b+6*d+n)%7
    
    if d == 29 and e==6:
        return 'april 19'
    elif d==28 and e==6 and m in [2,5,10,13,16,21,34,39]:
        return 'april 18'
    elif 22+d+e <= 31:
        return 'march' + str(22+d+e)
    else:
        return 'april' + str(d+e-9)
y = int(input("enter a value"))
print(easter(y))
# Out:
# enter a value12
# march25

# %%
import pandas as pd
data ={"nom":["jean","pierre"],"prenom":["dilane","kana"],"ages":[30,40]}
dataTable = pd.DataFrame(data)
print(dataTable)
# Out:
#       nom  prenom  ages
# 0    jean  dilane    30
# 1  pierre    kana    40

# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
treatment= pd.read_csv(("C:/Users/DILANE/Documents/treatment.csv.bz2"),sep = "\t")

# %%
treatment
# Out:
#       treat  age  educ      ethn  married     re74     re75      re78    u74  \
# 0      True   37    11     black     True      0.0      0.0   9930.05   True
# 1      True   30    12     black    False      0.0      0.0  24909.50   True
# 2      True   27    11     black    False      0.0      0.0   7506.15   True
# 3      True   33     8     black    False      0.0      0.0    289.79   True
# 4      True   22     9     black    False      0.0      0.0   4056.49   True
# ...     ...  ...   ...       ...      ...      ...      ...       ...    ...
# 2670  False   47     8     other     True  44667.4  33837.1  38568.70  False
# 2671  False   32     8     other     True  47022.4  67137.1  59109.10  False
# 2672  False   47    10     other     True  48198.0  47968.1  55710.30  False
# 2673  False   54     0  hispanic     True  49228.5  44221.0  20540.40  False
# 2674  False   40     8     other     True  50940.9  55500.0  53198.20  False
#
#         u75
# 0      True
# 1      True
# ...

# %%
treatment.columns
# Out:
# Index(['treat', 'age', 'educ', 'ethn', 'married', 're74', 're75', 're78',
#        'u74', 'u75'],
#       dtype='object')

# %%
treatment.dtypes
# Out:
# treat         bool
# age          int64
# educ         int64
# ethn        object
# married       bool
# re74       float64
# re75       float64
# re78       float64
# u74           bool
# u75           bool
# dtype: object

# %%
traitment.age.mean()
# Out:
# 34.22579439252336

# %%
plt.scatter(treatment.age,treatment.treat,s=1)
plt.xlabel("age")
plt.ylabel("participated")
# Out:
# Text(0, 0.5, 'participated')

# %%
plt.scatter(treatment.age,treatment.re74,s=1)
plt.xlabel("age")
plt.ylabel("revenu")
# Out:
# Text(0, 0.5, 'revenu')

# %%
from sklearn.datasets import load_digits

# %%
nmist = load_digits()
x=nmist.data
y=nmist.target
print(x)
print(y.shape)
print(x.shape)
Y=y[:25]
X=x[7:9]
print(x)
print(y)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# (1797,)
# (1797, 64)
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]

# %%
x[7].reshape((8,8))
# Out:
# array([[ 0.,  0.,  7.,  8., 13., 16., 15.,  1.],
#        [ 0.,  0.,  7.,  7.,  4., 11., 12.,  0.],
#        [ 0.,  0.,  0.,  0.,  8., 13.,  1.,  0.],
#        [ 0.,  4.,  8.,  8., 15., 15.,  6.,  0.],
#        [ 0.,  2., 11., 15., 15.,  4.,  0.,  0.],
#        [ 0.,  0.,  0., 16.,  5.,  0.,  0.,  0.],
#        [ 0.,  0.,  9., 15.,  1.,  0.,  0.,  0.],
#        [ 0.,  0., 13.,  5.,  0.,  0.,  0.,  0.]])

# %%
plt.imshow(x[7].reshape((8,8)),cmap="gray_r")

# %%
plt.imshow(x[5].reshape((8,8)),cmap="pink_r")

# %%
import pandas as pd
dime = pd.read_excel("DIME_work.xlsx")

# %%
dime
# Out:
#                                                 FOODS  Number of ingredients  \
# 0                           Mole poblano  y enmoladas                     25
# 1               Margarita de hielo de jamaica picante                     10
# 2               Tacos de champinones con mole de HIGO                     20
# 3                           Sopa seca de fideo vegana                     12
# 4                         Tortitas de camaron veganas                     15
# 5                     Sopa de lentejas en instant pot                      9
# 6                           Poppers jalapenos veganos                     10
# 7                                    Muffins de moras                      9
# 8              Enmoladas veganas con verduras y papas                      9
# 9                                      Sopa de camote                     18
# 10                                      Menudo vegano                     17
# ...

# %%
dime.columns
# Out:
# Index(['FOODS', 'Number of ingredients', 'Number of spies used', 'Total time',
#        'Prep time', 'Cook time', 'Appliances used'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(dime)
# Out:
# (array([[50.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [50.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [50.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [42.,  5.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  1.],
#         [47.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [45.,  3.,  0.,  0.,  1.,  0.,  0.,  0.,  0.,  1.],
#         [50.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.0, 144.0, 288.0, 432.0, 576.0, 720.0, 864.0, 1008.0, 1152.0,
#         1296.0, 1440.0], dtype=object),
#  <a list of 7 BarContainer objects>)

# %%
import seaborn as sns

# %%
sns.pairplot(dime)

# %%
sns.histplot(dime['Prep time'],color="green")
# Out:
# <AxesSubplot:xlabel='Prep time', ylabel='Count'>

# %%
plt.plot(dime['Prep time'],color="black")

# %%
sns.jointplot(x=dime['Total time'],y=dime['Number of ingredients'],color="yellow")

# %%
#exercise 2
import numpy as np
def f(x,θ):
    return np.cos(np.pi * θ *x ) * np.exp(-x)
θ_vals = np.linspace(0, 2, 10)
x = np.linspace(0, 5, 200)
fig, ax = plt.subplots()
for θ in θ_val:
    ax.plot(x, f(x,θ))
plt.show()

# %%
##exercicse 
import matplotlib.pyplot as plt
import numpy as np

α_values = [0.0,0.8,0.98]
T = 200
x = np.empty(T+1)
for α in α_values:
    x[0] = 0
    for t in range(T):
        x[t+1] = α*x[t]+np.random.normal()
        plt.plot(x,label=f'α={α}')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

α = 0.9
T = 200
x = np.empty(T)
x[0] = 0
for t in range(T-1):
    
    x[t+1] = α*x[t]+np.random.normal()
plt.plot(x)
plt.shoW()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-9fc5b80014b4> in <module>
#      10     x[t+1] = α*x[t]+np.random.normal()
#      11 plt.plot(x)
# ---> 12 plt.shoW()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shoW'

# %%
import pandas as pd 
Titanic_analysis = pd.read_excel("Titanic_analysis.xlsx")

# %%
Titanic_analysis
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic_analysis.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Titanic_analysis.describe().sum()
# Out:
# PassengerId    3824.353842
# Survived        893.870431
# Pclass          906.144713
# Age             924.770615
# SibSp           901.625751
# Parch           898.187651
# Fare           1538.591437
# dtype: float64

# %%
print(Titanic_analysis.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.hist(Titanic_analysis['Pclass'],color="blue")
# Out:
# (array([216.,   0.,   0.,   0.,   0., 184.,   0.,   0.,   0., 491.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.pairplot(Titanic_analysis)

# %%
sns.jointplot(x=Titanic_analysis['Pclass'],y=Titanic_analysis['Survived'],color="yellow")

# %%
sns.histplot(Titanic_analysis['Sex'],color="pink")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(x='Survived',data=Titanic_analysis,hue='Sex',kde=True)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Count'>

# %%
sns.barplot(x='Survived',y='Age',data=Titanic_analysis,hue="Sex")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.countplot(Titanic_analysis['Age'])
# Out:
# C:\Users\DILANE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='count'>
